# %%
import pandas as pd

# %%
data = pd.read_csv("addresses.csv")

# %%
data
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
# 3   4            4       24 Second Avenue       NaN     San Mateo
# 4   5            5       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US
# 3             CA       94401      US
# 4             CA       94401      US

# %%
data.tail()
# Out:
#     id  location_id                   address_1  address_2  \
# 16  17           17     409 South Spruce Avenue        NaN
# 17  18           18            114 Fifth Avenue        NaN
# 18  19           19         19 West 39th Avenue        NaN
# 19  20           21          123 El Camino Real        NaN
# 20  21           22  2013 Avenue of the fellows  Suite 100
#
#                    city state_province postal_code country
# 16  South San Francisco             CA       94080      US
# 17         Redwood City             CA       94063      US
# 18            San Mateo             CA       94403      US
# 19              Belmont             CA       94002      US
# 20        San Francisco             CA       94103      US

# %%
data.tail(3)
# Out:
#     id  location_id                   address_1  address_2           city  \
# 18  19           19         19 West 39th Avenue        NaN      San Mateo
# 19  20           21          123 El Camino Real        NaN        Belmont
# 20  21           22  2013 Avenue of the fellows  Suite 100  San Francisco
#
#    state_province postal_code country
# 18             CA       94403      US
# 19             CA       94002      US
# 20             CA       94103      US

# %%
data.columns
# Out:
# Index(['id', 'location_id', 'address_1', 'address_2', 'city', 'state_province',
#        'postal_code', 'country'],
#       dtype='object')

# %%
list(data.columns)
# Out:
# ['id',
#  'location_id',
#  'address_1',
#  'address_2',
#  'city',
#  'state_province',
#  'postal_code',
#  'country']

# %%
data.head(3)
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US

# %%
data[["city","location_id"]]
# Out:
#                    city  location_id
# 0          Redwood City            1
# 1             San Mateo            2
# 2             San Mateo            3
# 3             San Mateo            4
# 4             San Mateo            5
# 5            Menlo Park            6
# 6            Menlo Park            7
# 7            Menlo Park            8
# 8          Redwood City            9
# 9          Redwood City           10
# 10         Redwood City           11
# 11         Redwood City           12
# 12         Redwood City           13
# 13         Redwood City           14
# 14        San Francisco           15
# 15            Sunnyvale           16
# 16  South San Francisco           17
# 17         Redwood City           18
# 18            San Mateo           19
# 19              Belmont           21
# 20        San Francisco           22

# %%
data[['id','address_2']]
# Out:
#     id  address_2
# 0    1        NaN
# 1    2        NaN
# 2    3        NaN
# 3    4        NaN
# 4    5        NaN
# 5    6        NaN
# 6    7        NaN
# 7    8        NaN
# 8    9        NaN
# 9   10        NaN
# 10  11        NaN
# 11  12  2nd Floor
# 12  13        NaN
# 13  14        NaN
# 14  15        NaN
# 15  16        NaN
# 16  17        NaN
# 17  18        NaN
# 18  19        NaN
# 19  20        NaN
# 20  21  Suite 100

# %%
data.head(2)
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US

# %%
data[["state_province"]].head(2)
# Out:
#   state_province
# 0             CA
# 1             CA

# %%
type(data[["state_province"]].head(2))
# Out:
# pandas.core.frame.DataFrame

# %%
data["state_province"].head(2)
# Out:
# 0    CA
# 1    CA
# Name: state_province, dtype: object

# %%
type(data["state_province"].head(2))
# Out:
# pandas.core.series.Series

# %%
pd.read_excel("airline.xls")
# Out:
#     YEAR       Y      W       R      L      K
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361  0.3822  2.435  0.800
# 9   1957   4.420  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965   9.120  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %%
pd.read_excel("airline1.xls")
# Out:
#     YEAR       Y      W       R      L      K
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361  0.3822  2.435  0.800
# 9   1957   4.420  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965   9.120  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %%
d1=pd.read_excel("airline1.xls", sheet_name="Sheet2", header=None, names =["Year","A","B","C","D","E"])

# %%
pd.read_excel("airline1.xls", sheet_name="Sheet2", header=None, names =["Year","A","B"])
#the 1st 3 columns are considered as indices
# Out:
#                     Year      A      B
# 1952 2.265 0.310  0.3559  1.802  0.574
# 1953 2.731 0.322  0.3593  1.926  0.711
# 1954 3.025 0.335  0.4025  1.964  0.776
# 1955 3.562 0.350  0.3961  2.116  0.827
# 1956 3.979 0.361  0.3822  2.435  0.800
# 1957 4.420 0.379  0.3045  2.707  0.921
# 1958 4.563 0.391  0.3284  2.706  1.067
# 1959 5.385 0.426  0.3856  2.846  1.083
# 1960 5.554 0.441  0.3193  3.089  1.481
# 1961 5.465 0.460  0.3079  3.122  1.736
# 1962 5.825 0.485  0.3783  3.184  1.926
# 1963 6.876 0.506  0.4180  3.263  2.041
# 1964 7.823 0.538  0.5163  3.412  1.997
# 1965 9.120 0.564  0.5879  3.623  2.257

# %%
d1
# Out:
#     Year      A      B       C      D      E
# 0   1952  2.265  0.310  0.3559  1.802  0.574
# 1   1953  2.731  0.322  0.3593  1.926  0.711
# 2   1954  3.025  0.335  0.4025  1.964  0.776
# 3   1955  3.562  0.350  0.3961  2.116  0.827
# 4   1956  3.979  0.361  0.3822  2.435  0.800
# 5   1957  4.420  0.379  0.3045  2.707  0.921
# 6   1958  4.563  0.391  0.3284  2.706  1.067
# 7   1959  5.385  0.426  0.3856  2.846  1.083
# 8   1960  5.554  0.441  0.3193  3.089  1.481
# 9   1961  5.465  0.460  0.3079  3.122  1.736
# 10  1962  5.825  0.485  0.3783  3.184  1.926
# 11  1963  6.876  0.506  0.4180  3.263  2.041
# 12  1964  7.823  0.538  0.5163  3.412  1.997
# 13  1965  9.120  0.564  0.5879  3.623  2.257

# %%
d1.to_csv("test1.csv", index=False)

# %%
d1.to_excel("test2.xlsx", index=False)

# %%
d1.head()
# Out:
#    Year      A      B       C      D      E
# 0  1952  2.265  0.310  0.3559  1.802  0.574
# 1  1953  2.731  0.322  0.3593  1.926  0.711
# 2  1954  3.025  0.335  0.4025  1.964  0.776
# 3  1955  3.562  0.350  0.3961  2.116  0.827
# 4  1956  3.979  0.361  0.3822  2.435  0.800

# %%
d1.tail()
# Out:
#     Year      A      B       C      D      E
# 9   1961  5.465  0.460  0.3079  3.122  1.736
# 10  1962  5.825  0.485  0.3783  3.184  1.926
# 11  1963  6.876  0.506  0.4180  3.263  2.041
# 12  1964  7.823  0.538  0.5163  3.412  1.997
# 13  1965  9.120  0.564  0.5879  3.623  2.257

# %%
type(d1)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
d1.columns
# Out:
# Index(['Year', 'A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
list(d1.columns)
# Out:
# ['Year', 'A', 'B', 'C', 'D', 'E']

# %%
d1[["Year","B"]]
# Out:
#     Year      B
# 0   1952  0.310
# 1   1953  0.322
# 2   1954  0.335
# 3   1955  0.350
# 4   1956  0.361
# 5   1957  0.379
# 6   1958  0.391
# 7   1959  0.426
# 8   1960  0.441
# 9   1961  0.460
# 10  1962  0.485
# 11  1963  0.506
# 12  1964  0.538
# 13  1965  0.564

# %%
pd.read_csv("https://raw.githubusercontent.com/adamerose/datasets/master/titanic.csv")
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/WorldDBTables/CountryTable.csv")
# Out:
#     code          name      continent                     region  \
# 0    ABW         Aruba  North America                  Caribbean
# 1    AFG   Afghanistan           Asia  Southern and Central Asia
# 2    AGO        Angola         Africa             Central Africa
# 3    AIA      Anguilla  North America                  Caribbean
# 4    ALB       Albania         Europe            Southern Europe
# ..   ...           ...            ...                        ...
# 234  YEM         Yemen           Asia                Middle East
# 235  YuG    Yugoslavia         Europe            Southern Europe
# 236  ZAF  South Africa         Africa            Southern Africa
# 237  ZMB        Zambia         Africa             Eastern Africa
# 238  ZWE      Zimbabwe         Africa             Eastern Africa
#
#      surface_area independence_year  population life_expectancy       gnp  \
# 0           193.0              NuLL      103000            78.4     828.0
# ...

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
d2=pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_per_game.html")

# %%
type(d2)
# Out:
# list

# %%
len(d2)
# Out:
# 1

# %%
d2[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  18.9  2.2   4.9  ...  .784
# 1      2    Jordan Adams  SG  20  MEM  30   0   8.3  1.2   2.9  ...  .609
# 2      3    Steven Adams   C  21  OKC  70  67  25.3  3.1   5.7  ...  .502
# 3      4     Jeff Adrien  PF  28  MIN  17   0  12.6  1.1   2.6  ...  .579
# 4      5   Arron Afflalo  SG  29  TOT  78  72  32.1  4.8  11.3  ...  .843
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  32.0  5.9  12.7  ...  .655
# 671  490  Thaddeus Young  PF  26  MIN  48  48  33.4  6.0  13.4  ...  .682
# 672  490  Thaddeus Young  PF  26  BRK  28  20  29.6  5.8  11.7  ...  .606
# 673  491     Cody Zeller   C  22  CHO  62  45  24.0  2.8   6.0  ...  .774
# 674  492    Tyler Zeller   C  25  BOS  82  59  21.1  4.1   7.5  ...  .823
#
#      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
d2[0].to_csv("test3.csv", index=False)

# %%
len(d2[0])
# Out:
# 675

# %%
type(d2[0])
# Out:
# pandas.core.frame.DataFrame
