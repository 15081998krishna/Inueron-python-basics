# %%
import pandas as pd

# %%
pd.read_csv("addresses.csv")
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
#always use raw link to load a csv from gitbub
data=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail(8)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket    Fare Cabin Embarked
# 883    male  28.0      0      0  C.A./SOTON 34068  10.500   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.050   NaN        S
# ...

# %%
#to know data types of columns
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#to know a detail info on data 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#to know count, mean, std, 5quantifiers of numerical data
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#when there is no numerical data it gives count, uniquq,top and max. frequency
data[["Name","Ticket","Sex"]].describe()
# Out:
#                            Name  Ticket   Sex
# count                       891     891   891
# unique                      891     681     2
# top     Braund, Mr. Owen Harris  347082  male
# freq                          1       7   577

# %%
data[["Name","Ticket","Age","Sex"]].describe()
# Out:
#               Age
# count  714.000000
# mean    29.699118
# std     14.526497
# min      0.420000
# 25%     20.125000
# 50%     28.000000
# 75%     38.000000
# max     80.000000

# %%
type(data.dtypes)
# Out:
# pandas.core.series.Series

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.dtypes
# the 1st colums are indices and 2nd column are data for this series
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data["Fare"]
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
data[["Fare"]]
# Out:
#         Fare
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# ..       ...
# 886  13.0000
# 887  30.0000
# 888  23.4500
# 889  30.0000
# 890   7.7500
#
# [891 rows x 1 columns]

# %%
type(data["Fare"])
# Out:
# pandas.core.series.Series

# %%
type(data[["Fare"]])
# Out:
# pandas.core.frame.DataFrame

# %%
data.dtypes=="object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
data.dtypes[data.dtypes=="object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
data.dtypes[data.dtypes=="object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
type(list(data.dtypes[data.dtypes=="object"])[0])
# Out:
# numpy.dtype[object_]

# %%
data.dtypes[data.dtypes=="object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
data[data.dtypes[data.dtypes=="object"].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
data[data.dtypes[data.dtypes=="object"].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data[data["Survived"]==0]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
data["Survived"]==0
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Survived, Length: 891, dtype: bool

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data[(data["Survived"]==0)  & (data["Sex"]=="male")]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
data[(data["Survived"]==0)  & (data["Sex"]=="male")] .count()
# Out:
# PassengerId    468
# Survived       468
# Pclass         468
# Name           468
# Sex            468
# Age            360
# SibSp          468
# Parch          468
# Ticket         468
# Fare           468
# Cabin           62
# Embarked       468
# dtype: int64

# %%
len(data[(data["Survived"]==0)  & (data["Sex"]=="male")])
# Out:
# 468

# %%
len(data[(data["Survived"]==0)  & (data["Sex"]=="female")])
# Out:
# 81

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
len(data[data["Sex"]=="female"])
# Out:
# 314

# %%
len(data[data["Sex"]=="male"])
# Out:
# 577

# %%
data["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
len(data[(data["Survived"]==1)  & (data["Sex"]=="male")])
# Out:
# 109

# %%
len(data[(data["Survived"]==1)  & (data["Sex"]=="female")])
# Out:
# 233

# %%
len(data)
# Out:
# 891

# %%
max(data["Fare"])
# Out:
# 512.3292

# %%
data[data["Fare"]==max(data["Fare"])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
data[data["Fare"]==max(data["Fare"])][["Name","Survived"]]
# Out:
#                                    Name  Survived
# 258                    Ward, Miss. Anna         1
# 679  Cardeza, Mr. Thomas Drake Martinez         1
# 737              Lesurer, Mr. Gustave J         1

# %%
min(data["Fare"])
# Out:
# 0.0

# %%
data[data["Fare"]==min(data["Fare"])]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
data[data["Fare"]==min(data["Fare"])][["Name","Survived"]]
# Out:
#                                  Name  Survived
# 179               Leonard, Mr. Lionel         0
# 263             Harrison, Mr. William         0
# 271      Tornquist, Mr. William Henry         1
# 277       Parkes, Mr. Francis "Frank"         0
# 302   Johnson, Mr. William Cahoone Jr         0
# 413    Cunningham, Mr. Alfred Fleming         0
# 466             Campbell, Mr. William         0
# 481  Frost, Mr. Anthony Wood "Archie"         0
# 597               Johnson, Mr. Alfred         0
# 633     Parr, Mr. William Henry Marsh         0
# 674        Watson, Mr. Ennis Hastings         0
# 732              Knight, Mr. Robert J         0
# 806            Andrews, Mr. Thomas Jr         0
# 815                  Fry, Mr. Richard         0
# 822   Reuchlin, Jonkheer. John George         0

# %%
data[data["Fare"]==min(data["Fare"])][["Survived"]].value_counts()
# Out:
# Survived
# 0           14
# 1            1
# dtype: int64

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data["Cabin"].isna()
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Cabin, Length: 891, dtype: bool

# %%
data[data["Cabin"].isna()==False]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data[data["Cabin"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
data[data["Cabin"].isna()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data['new_col']="Krishn"

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked new_col
# 0      0         A/5 21171   7.2500   NaN        S  Krishn
# 1      0          PC 17599  71.2833   C85        C  Krishn
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Krishn
# 3      0            113803  53.1000  C123        S  Krishn
# ...

# %%
data["new_Name"]=data["Name"]

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked new_col  \
# 0      0         A/5 21171   7.2500   NaN        S  Krishn
# 1      0          PC 17599  71.2833   C85        C  Krishn
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Krishn
# 3      0            113803  53.1000  C123        S  Krishn
# ...

# %%
data["age_pclass"]=data["Age"]+data["Pclass"]

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked new_col  \
# 0      0         A/5 21171   7.2500   NaN        S  Krishn
# 1      0          PC 17599  71.2833   C85        C  Krishn
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Krishn
# 3      0            113803  53.1000  C123        S  Krishn
# ...

# %%
data.drop("new_col",axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked new_col  \
# 0      0         A/5 21171   7.2500   NaN        S  Krishn
# 1      0          PC 17599  71.2833   C85        C  Krishn
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Krishn
# 3      0            113803  53.1000  C123        S  Krishn
# ...

# %%
data.drop("new_col", axis=1,inplace=True)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  \
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
#
# ...

# %%
data.drop(1, inplace=True)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 5                                Moran, Mr. James    male   NaN      0      0
# ...

# %%
data.iloc[1]
# Out:
# PassengerId                         3
# Survived                            1
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Sex                            female
# Age                              26.0
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# new_Name       Heikkinen, Miss. Laina
# age_pclass                       29.0
# Name: 2, dtype: object

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                       Braund, Mr. Owen Harris    male  22.0      1      0
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male   NaN      0      0
#
#              Ticket     Fare Cabin Embarked  \
# 0         A/5 21171   7.2500   NaN        S
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
# 5            330877   8.4583   NaN        Q
#
# ...

# %%
data.loc[2]
# Out:
# PassengerId                         3
# Survived                            1
# Pclass                              3
# Name           Heikkinen, Miss. Laina
# Sex                            female
# Age                              26.0
# SibSp                               0
# Parch                               0
# Ticket               STON/O2. 3101282
# Fare                            7.925
# Cabin                             NaN
# Embarked                            S
# new_Name       Heikkinen, Miss. Laina
# age_pclass                       29.0
# Name: 2, dtype: object

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                       Braund, Mr. Owen Harris    male  22.0      1      0
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male   NaN      0      0
#
#              Ticket     Fare Cabin Embarked  \
# 0         A/5 21171   7.2500   NaN        S
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
# 5            330877   8.4583   NaN        Q
#
# ...

# %%
data.iloc[2:6]
# Out:
#    PassengerId  Survived  Pclass  \
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male   NaN      0      0
# 6                       McCarthy, Mr. Timothy J    male  54.0      0      0
#
#    Ticket     Fare Cabin Embarked  \
# 3  113803  53.1000  C123        S
# 4  373450   8.0500   NaN        S
# 5  330877   8.4583   NaN        Q
# 6   17463  51.8625   E46        S
#
#                                        new_Name  age_pclass
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)        36.0
# 4                      Allen, Mr. William Henry        38.0
# ...

# %%
data[data['Cabin'] != 'NaN']
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 5                                Moran, Mr. James    male   NaN      0      0
# ...

# %%
data.iloc[:3]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 2            3         1       3
# 3            4         1       1
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                       Braund, Mr. Owen Harris    male  22.0      1      0
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
#
#              Ticket    Fare Cabin Embarked  \
# 0         A/5 21171   7.250   NaN        S
# 2  STON/O2. 3101282   7.925   NaN        S
# 3            113803  53.100  C123        S
#
#                                        new_Name  age_pclass
# 0                       Braund, Mr. Owen Harris        25.0
# 2                        Heikkinen, Miss. Laina        29.0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)        36.0

# %%
data.loc[:3]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 2            3         1       3
# 3            4         1       1
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                       Braund, Mr. Owen Harris    male  22.0      1      0
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
#
#              Ticket    Fare Cabin Embarked  \
# 0         A/5 21171   7.250   NaN        S
# 2  STON/O2. 3101282   7.925   NaN        S
# 3            113803  53.100  C123        S
#
#                                        new_Name  age_pclass
# 0                       Braund, Mr. Owen Harris        25.0
# 2                        Heikkinen, Miss. Laina        29.0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)        36.0

# %%
data.drop(3,inplace=True)

# %%
data.loc[:4]
# Out:
#    PassengerId  Survived  Pclass                      Name     Sex   Age  \
# 0            1         0       3   Braund, Mr. Owen Harris    male  22.0
# 2            3         1       3    Heikkinen, Miss. Laina  female  26.0
# 4            5         0       3  Allen, Mr. William Henry    male  35.0
#
#    SibSp  Parch            Ticket   Fare Cabin Embarked  \
# 0      1      0         A/5 21171  7.250   NaN        S
# 2      0      0  STON/O2. 3101282  7.925   NaN        S
# 4      0      0            373450  8.050   NaN        S
#
#                    new_Name  age_pclass
# 0   Braund, Mr. Owen Harris        25.0
# 2    Heikkinen, Miss. Laina        29.0
# 4  Allen, Mr. William Henry        38.0

# %%
data.iloc[:4]
# Out:
#    PassengerId  Survived  Pclass                      Name     Sex   Age  \
# 0            1         0       3   Braund, Mr. Owen Harris    male  22.0
# 2            3         1       3    Heikkinen, Miss. Laina  female  26.0
# 4            5         0       3  Allen, Mr. William Henry    male  35.0
# 5            6         0       3          Moran, Mr. James    male   NaN
#
#    SibSp  Parch            Ticket    Fare Cabin Embarked  \
# 0      1      0         A/5 21171  7.2500   NaN        S
# 2      0      0  STON/O2. 3101282  7.9250   NaN        S
# 4      0      0            373450  8.0500   NaN        S
# 5      0      0            330877  8.4583   NaN        Q
#
#                    new_Name  age_pclass
# 0   Braund, Mr. Owen Harris        25.0
# 2    Heikkinen, Miss. Laina        29.0
# 4  Allen, Mr. William Henry        38.0
# 5          Moran, Mr. James         NaN

# %%
len(data[data["Age"]>35])
# Out:
# 216

# %%
data[data["Age"]>35]
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# 25            26         1       3
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass                      Name     Sex   Age  \
# 0            1         0       3   Braund, Mr. Owen Harris    male  22.0
# 2            3         1       3    Heikkinen, Miss. Laina  female  26.0
# 4            5         0       3  Allen, Mr. William Henry    male  35.0
# 5            6         0       3          Moran, Mr. James    male   NaN
# 6            7         0       1   McCarthy, Mr. Timothy J    male  54.0
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0      1      0         A/5 21171   7.2500   NaN        S
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4      0      0            373450   8.0500   NaN        S
# 5      0      0            330877   8.4583   NaN        Q
# 6      0      0             17463  51.8625   E46        S
#
#                    new_Name  age_pclass
# 0   Braund, Mr. Owen Harris        25.0
# 2    Heikkinen, Miss. Laina        29.0
# 4  Allen, Mr. William Henry        38.0
# ...

# %%
data.loc[0:5][["Survived","Pclass"]]
# Out:
#    Survived  Pclass
# 0         0       3
# 2         1       3
# 4         0       3
# 5         0       3

# %%
data.loc[101:105,["Survived","Pclass"]]
# Out:
#      Survived  Pclass
# 101         0       3
# 102         0       1
# 103         0       3
# 104         0       3
# 105         0       3

# %%
data.loc[3:6,['PassengerId','Survived','Pclass']]
# Out:
#    PassengerId  Survived  Pclass
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1

# %%
data.iloc[23:30,[3,6]]
# Out:
#                                                  Name  SibSp
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...      1
# 26                            Emir, Mr. Farred Chehab      0
# 27                     Fortune, Mr. Charles Alexander      3
# 28                      O'Dwyer, Miss. Ellen "Nellie"      0
# 29                                Todoroff, Mr. Lalio      0
# 30                           Uruchurtu, Don. Manuel E      0
# 31     Spencer, Mrs. William Augustus (Marie Eugenie)      1

# %%
data.loc[2:4,["Fare","Cabin","Embarked"]]
# Out:
#     Fare Cabin Embarked
# 2  7.925   NaN        S
# 4  8.050   NaN        S

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass                      Name     Sex   Age  \
# 0            1         0       3   Braund, Mr. Owen Harris    male  22.0
# 2            3         1       3    Heikkinen, Miss. Laina  female  26.0
# 4            5         0       3  Allen, Mr. William Henry    male  35.0
# 5            6         0       3          Moran, Mr. James    male   NaN
# 6            7         0       1   McCarthy, Mr. Timothy J    male  54.0
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0      1      0         A/5 21171   7.2500   NaN        S
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4      0      0            373450   8.0500   NaN        S
# 5      0      0            330877   8.4583   NaN        Q
# 6      0      0             17463  51.8625   E46        S
#
#                    new_Name  age_pclass
# 0   Braund, Mr. Owen Harris        25.0
# 2    Heikkinen, Miss. Laina        29.0
# 4  Allen, Mr. William Henry        38.0
# ...

# %%
data.iloc[2:4,9:12]
# Out:
#      Fare Cabin Embarked
# 4  8.0500   NaN        S
# 5  8.4583   NaN        Q

# %%
data.iloc[:,0:2]
# Out:
#      PassengerId  Survived
# 0              1         0
# 2              3         1
# 4              5         0
# 5              6         0
# 6              7         0
# ..           ...       ...
# 886          887         0
# 887          888         1
# 888          889         0
# 889          890         1
# 890          891         0
#
# [889 rows x 2 columns]

# %%
data.loc[:,["PassengerId","Survived"]]
# Out:
#      PassengerId  Survived
# 0              1         0
# 2              3         1
# 4              5         0
# 5              6         0
# 6              7         0
# ..           ...       ...
# 886          887         0
# 887          888         1
# 888          889         0
# 889          890         1
# 890          891         0
#
# [889 rows x 2 columns]

# %%
d1=data.iloc[1:5,[2,3,4,5,7,9]]

# %%
d1
# Out:
#    Pclass                      Name     Sex   Age  Parch     Fare
# 2       3    Heikkinen, Miss. Laina  female  26.0      0   7.9250
# 4       3  Allen, Mr. William Henry    male  35.0      0   8.0500
# 5       3          Moran, Mr. James    male   NaN      0   8.4583
# 6       1   McCarthy, Mr. Timothy J    male  54.0      0  51.8625

# %%
data["Age"]>35
# Out:
# 0      False
# 2      False
# 4      False
# 5      False
# 6       True
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 889, dtype: bool

# %%
data[data["Age"]>35]
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# 25            26         1       3
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
data[(data["Age"]>35) & (data["Pclass"]==1)]
#use () for the functioning of multi boolean functions in the code, else it errors out
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 30            31         0       1
# 35            36         0       1
# 52            53         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 857          858         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 30                            Uruchurtu, Don. Manuel E    male  40.0      0
# 35                      Holverson, Mr. Alexander Oskar    male  42.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
d1
# Out:
#    Pclass                      Name     Sex   Age  Parch     Fare
# 2       3    Heikkinen, Miss. Laina  female  26.0      0   7.9250
# 4       3  Allen, Mr. William Henry    male  35.0      0   8.0500
# 5       3          Moran, Mr. James    male   NaN      0   8.4583
# 6       1   McCarthy, Mr. Timothy J    male  54.0      0  51.8625

# %%
d1.reset_index()
# Out:
#    index  Pclass                      Name     Sex   Age  Parch     Fare
# 0      2       3    Heikkinen, Miss. Laina  female  26.0      0   7.9250
# 1      4       3  Allen, Mr. William Henry    male  35.0      0   8.0500
# 2      5       3          Moran, Mr. James    male   NaN      0   8.4583
# 3      6       1   McCarthy, Mr. Timothy J    male  54.0      0  51.8625

# %%
d1.set_index("Name")
# Out:
#                           Pclass     Sex   Age  Parch     Fare
# Name
# Heikkinen, Miss. Laina         3  female  26.0      0   7.9250
# Allen, Mr. William Henry       3    male  35.0      0   8.0500
# Moran, Mr. James               3    male   NaN      0   8.4583
# McCarthy, Mr. Timothy J        1    male  54.0      0  51.8625

# %%
d1
# Out:
#    Pclass                      Name     Sex   Age  Parch     Fare
# 2       3    Heikkinen, Miss. Laina  female  26.0      0   7.9250
# 4       3  Allen, Mr. William Henry    male  35.0      0   8.0500
# 5       3          Moran, Mr. James    male   NaN      0   8.4583
# 6       1   McCarthy, Mr. Timothy J    male  54.0      0  51.8625

# %%
d1.set_index("Name", inplace=True)

# %%
d1
# Out:
#                           Pclass     Sex   Age  Parch     Fare
# Name
# Heikkinen, Miss. Laina         3  female  26.0      0   7.9250
# Allen, Mr. William Henry       3    male  35.0      0   8.0500
# Moran, Mr. James               3    male   NaN      0   8.4583
# McCarthy, Mr. Timothy J        1    male  54.0      0  51.8625

# %%
d1.dropna()
# Out:
#                           Pclass     Sex   Age  Parch     Fare
# Name
# Heikkinen, Miss. Laina         3  female  26.0      0   7.9250
# Allen, Mr. William Henry       3    male  35.0      0   8.0500
# McCarthy, Mr. Timothy J        1    male  54.0      0  51.8625

# %%
d1.dropna(inplace=True)

# %%
d1
# Out:
#                           Pclass     Sex   Age  Parch     Fare
# Name
# Heikkinen, Miss. Laina         3  female  26.0      0   7.9250
# Allen, Mr. William Henry       3    male  35.0      0   8.0500
# McCarthy, Mr. Timothy J        1    male  54.0      0  51.8625

# %%
d1.dropna(axis=1)
# Out:
#                           Pclass     Sex   Age  Parch     Fare
# Name
# Heikkinen, Miss. Laina         3  female  26.0      0   7.9250
# Allen, Mr. William Henry       3    male  35.0      0   8.0500
# McCarthy, Mr. Timothy J        1    male  54.0      0  51.8625

# %%
d1=data.iloc[2:6,[2,3,4,5,7,9]]

# %%
d1
# Out:
#    Pclass                            Name   Sex   Age  Parch     Fare
# 4       3        Allen, Mr. William Henry  male  35.0      0   8.0500
# 5       3                Moran, Mr. James  male   NaN      0   8.4583
# 6       1         McCarthy, Mr. Timothy J  male  54.0      0  51.8625
# 7       3  Palsson, Master. Gosta Leonard  male   2.0      1  21.0750

# %%
d1.dropna(axis=1)
# Out:
#    Pclass                            Name   Sex  Parch     Fare
# 4       3        Allen, Mr. William Henry  male      0   8.0500
# 5       3                Moran, Mr. James  male      0   8.4583
# 6       1         McCarthy, Mr. Timothy J  male      0  51.8625
# 7       3  Palsson, Master. Gosta Leonard  male      1  21.0750

# %%
d1.dropna(axis=1, thresh=4)
# Out:
#    Pclass                            Name   Sex  Parch     Fare
# 4       3        Allen, Mr. William Henry  male      0   8.0500
# 5       3                Moran, Mr. James  male      0   8.4583
# 6       1         McCarthy, Mr. Timothy J  male      0  51.8625
# 7       3  Palsson, Master. Gosta Leonard  male      1  21.0750

# %%
d1.dropna(axis=1,thresh=1)
#threshold implies min.number of non-na values to drop the column
# Out:
#    Pclass                            Name   Sex   Age  Parch     Fare
# 4       3        Allen, Mr. William Henry  male  35.0      0   8.0500
# 5       3                Moran, Mr. James  male   NaN      0   8.4583
# 6       1         McCarthy, Mr. Timothy J  male  54.0      0  51.8625
# 7       3  Palsson, Master. Gosta Leonard  male   2.0      1  21.0750

# %%
d1
# Out:
#    Pclass                            Name   Sex   Age  Parch     Fare
# 4       3        Allen, Mr. William Henry  male  35.0      0   8.0500
# 5       3                Moran, Mr. James  male   NaN      0   8.4583
# 6       1         McCarthy, Mr. Timothy J  male  54.0      0  51.8625
# 7       3  Palsson, Master. Gosta Leonard  male   2.0      1  21.0750

# %%
d1.fillna(d1["Age"].mean(), inplace=True)

# %%
d1
# Out:
#    Pclass                            Name   Sex        Age  Parch     Fare
# 4       3        Allen, Mr. William Henry  male  35.000000      0   8.0500
# 5       3                Moran, Mr. James  male  30.333333      0   8.4583
# 6       1         McCarthy, Mr. Timothy J  male  54.000000      0  51.8625
# 7       3  Palsson, Master. Gosta Leonard  male   2.000000      1  21.0750

# %%
d1.dtypes
# Out:
# Pclass      int64
# Name       object
# Sex        object
# Age       float64
# Parch       int64
# Fare      float64
# dtype: object

# %%
d1.groupby("Sex").sum()['Fare']
# Out:
# /tmp/ipykernel_102/2297806983.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   d1.groupby("Sex").sum()['Fare']
# Sex
# male    89.4458
# Name: Fare, dtype: float64

# %%
d1.groupby("Sex").mean()['Fare']
# Out:
# /tmp/ipykernel_102/4033972064.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   d1.groupby("Sex").mean()['Fare']
# Sex
# male    22.36145
# Name: Fare, dtype: float64

# %%
d2=data.iloc[0:4,0:5]

# %%
d2
# Out:
#    PassengerId  Survived  Pclass                      Name     Sex
# 0            1         0       3   Braund, Mr. Owen Harris    male
# 2            3         1       3    Heikkinen, Miss. Laina  female
# 4            5         0       3  Allen, Mr. William Henry    male
# 5            6         0       3          Moran, Mr. James    male

# %%
d3=pd.concat([d1,d2])

# %%
d3
# Out:
#    Pclass                            Name     Sex        Age  Parch     Fare  \
# 4       3        Allen, Mr. William Henry    male  35.000000    0.0   8.0500
# 5       3                Moran, Mr. James    male  30.333333    0.0   8.4583
# 6       1         McCarthy, Mr. Timothy J    male  54.000000    0.0  51.8625
# 7       3  Palsson, Master. Gosta Leonard    male   2.000000    1.0  21.0750
# 0       3         Braund, Mr. Owen Harris    male        NaN    NaN      NaN
# 2       3          Heikkinen, Miss. Laina  female        NaN    NaN      NaN
# 4       3        Allen, Mr. William Henry    male        NaN    NaN      NaN
# 5       3                Moran, Mr. James    male        NaN    NaN      NaN
#
#    PassengerId  Survived
# 4          NaN       NaN
# 5          NaN       NaN
# 6          NaN       NaN
# 7          NaN       NaN
# 0          1.0       0.0
# 2          3.0       1.0
# 4          5.0       0.0
# 5          6.0       0.0

# %%
d3.groupby("Sex").sum()
# Out:
# /tmp/ipykernel_102/3837684923.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   d3.groupby("Sex").sum()
#         Pclass         Age  Parch     Fare  PassengerId  Survived
# Sex
# female       3    0.000000    0.0   0.0000          3.0       1.0
# male        19  121.333333    1.0  89.4458         12.0       0.0

# %%
d3.groupby("Sex").sum()["Fare"]
# Out:
# /tmp/ipykernel_102/1886806470.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   d3.groupby("Sex").sum()["Fare"]
# Sex
# female     0.0000
# male      89.4458
# Name: Fare, dtype: float64

# %%
pd.concat([d1,d2])
# Out:
#    Pclass                            Name     Sex        Age  Parch     Fare  \
# 4       3        Allen, Mr. William Henry    male  35.000000    0.0   8.0500
# 5       3                Moran, Mr. James    male  30.333333    0.0   8.4583
# 6       1         McCarthy, Mr. Timothy J    male  54.000000    0.0  51.8625
# 7       3  Palsson, Master. Gosta Leonard    male   2.000000    1.0  21.0750
# 0       3         Braund, Mr. Owen Harris    male        NaN    NaN      NaN
# 2       3          Heikkinen, Miss. Laina  female        NaN    NaN      NaN
# 4       3        Allen, Mr. William Henry    male        NaN    NaN      NaN
# 5       3                Moran, Mr. James    male        NaN    NaN      NaN
#
#    PassengerId  Survived
# 4          NaN       NaN
# 5          NaN       NaN
# 6          NaN       NaN
# 7          NaN       NaN
# 0          1.0       0.0
# 2          3.0       1.0
# 4          5.0       0.0
# 5          6.0       0.0

# %%
pd.concat([d1,d2], axis=1)
# Out:
#    Pclass                            Name   Sex        Age  Parch     Fare  \
# 4     3.0        Allen, Mr. William Henry  male  35.000000    0.0   8.0500
# 5     3.0                Moran, Mr. James  male  30.333333    0.0   8.4583
# 6     1.0         McCarthy, Mr. Timothy J  male  54.000000    0.0  51.8625
# 7     3.0  Palsson, Master. Gosta Leonard  male   2.000000    1.0  21.0750
# 0     NaN                             NaN   NaN        NaN    NaN      NaN
# 2     NaN                             NaN   NaN        NaN    NaN      NaN
#
#    PassengerId  Survived  Pclass                      Name     Sex
# 4          5.0       0.0     3.0  Allen, Mr. William Henry    male
# 5          6.0       0.0     3.0          Moran, Mr. James    male
# 6          NaN       NaN     NaN                       NaN     NaN
# 7          NaN       NaN     NaN                       NaN     NaN
# 0          1.0       0.0     3.0   Braund, Mr. Owen Harris    male
# ...

# %%
d1
# Out:
#    Pclass                            Name   Sex        Age  Parch     Fare
# 4       3        Allen, Mr. William Henry  male  35.000000      0   8.0500
# 5       3                Moran, Mr. James  male  30.333333      0   8.4583
# 6       1         McCarthy, Mr. Timothy J  male  54.000000      0  51.8625
# 7       3  Palsson, Master. Gosta Leonard  male   2.000000      1  21.0750

# %%
d2
# Out:
#    PassengerId  Survived  Pclass                      Name     Sex
# 0            1         0       3   Braund, Mr. Owen Harris    male
# 2            3         1       3    Heikkinen, Miss. Laina  female
# 4            5         0       3  Allen, Mr. William Henry    male
# 5            6         0       3          Moran, Mr. James    male

# %%
def f1(x):
    return x/2

# %%
d1
# Out:
#    Pclass                            Name   Sex        Age  Parch     Fare
# 4       3        Allen, Mr. William Henry  male  35.000000      0   8.0500
# 5       3                Moran, Mr. James  male  30.333333      0   8.4583
# 6       1         McCarthy, Mr. Timothy J  male  54.000000      0  51.8625
# 7       3  Palsson, Master. Gosta Leonard  male   2.000000      1  21.0750

# %%
d1["nen1"]=d1["Age"].apply(f1)

# %%
d1
# Out:
#    Pclass                            Name   Sex        Age  Parch     Fare  \
# 4       3        Allen, Mr. William Henry  male  35.000000      0   8.0500
# 5       3                Moran, Mr. James  male  30.333333      0   8.4583
# 6       1         McCarthy, Mr. Timothy J  male  54.000000      0  51.8625
# 7       3  Palsson, Master. Gosta Leonard  male   2.000000      1  21.0750
#
#         nen1
# 4  17.500000
# 5  15.166667
# 6  27.000000
# 7   1.000000

# %%
d2
# Out:
#    PassengerId  Survived  Pclass                      Name     Sex
# 0            1         0       3   Braund, Mr. Owen Harris    male
# 2            3         1       3    Heikkinen, Miss. Laina  female
# 4            5         0       3  Allen, Mr. William Henry    male
# 5            6         0       3          Moran, Mr. James    male

# %%
d2["name_len"]=d2["Name"].apply(len)

# %%
d2
# Out:
#    PassengerId  Survived  Pclass                      Name     Sex  name_len
# 0            1         0       3   Braund, Mr. Owen Harris    male        23
# 2            3         1       3    Heikkinen, Miss. Laina  female        22
# 4            5         0       3  Allen, Mr. William Henry    male        24
# 5            6         0       3          Moran, Mr. James    male        16

# %%
d2.drop("nee",axis=1, inplace=True)

# %%
d2
# Out:
#    PassengerId  Survived  Pclass                      Name     Sex  name_len
# 0            1         0       3   Braund, Mr. Owen Harris    male        23
# 2            3         1       3    Heikkinen, Miss. Laina  female        22
# 4            5         0       3  Allen, Mr. William Henry    male        24
# 5            6         0       3          Moran, Mr. James    male        16

# %%
import math

# %%
def c1(x):
    if x<3:
        return x
    else:
        return math.log2(x)

# %%
d2["nen"]=d2["PassengerId"].apply(c1)

# %%
d2
# Out:
#    PassengerId  Survived  Pclass                      Name     Sex  name_len  \
# 0            1         0       3   Braund, Mr. Owen Harris    male        23
# 2            3         1       3    Heikkinen, Miss. Laina  female        22
# 4            5         0       3  Allen, Mr. William Henry    male        24
# 5            6         0       3          Moran, Mr. James    male        16
#
#         nen
# 0  1.000000
# 2  1.584963
# 4  2.321928
# 5  2.584963

# %%
def d1(x):
    if x=="male":
        return 1
    else:
        return 0

# %%
d2["Sex_c1"]=d2["Sex"].apply(d1)

# %%
d2
# Out:
#    PassengerId  Survived  Pclass                      Name     Sex  name_len  \
# 0            1         0       3   Braund, Mr. Owen Harris    male        23
# 2            3         1       3    Heikkinen, Miss. Laina  female        22
# 4            5         0       3  Allen, Mr. William Henry    male        24
# 5            6         0       3          Moran, Mr. James    male        16
#
#         nen  Sex_c1
# 0  1.000000       1
# 2  1.584963       0
# 4  2.321928       1
# 5  2.584963       1

# %%
data.head(9)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 2             3         1       3
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ...

# %%
def t1(x):
    if x<20:
        return "A"
    elif x<40:
        return "B"
    else:
        return "C"

# %%
data['Fare_group'] = data['Fare'].apply(t1)

# %%
data.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 2             3         1       3
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# ...

# %%
d2
# Out:
#    PassengerId  Survived  Pclass                      Name     Sex  name_len  \
# 0            1         0       3   Braund, Mr. Owen Harris    male        23
# 2            3         1       3    Heikkinen, Miss. Laina  female        22
# 4            5         0       3  Allen, Mr. William Henry    male        24
# 5            6         0       3          Moran, Mr. James    male        16
#
#         nen  Sex_c1
# 0  1.000000       1
# 2  1.584963       0
# 4  2.321928       1
# 5  2.584963       1

# %%
d2["Pclass"]=
# Out:
#   Cell In [197], line 1
#     d2["Pclass"]=[1,2,,1]
#                       ^
# SyntaxError: invalid syntax
